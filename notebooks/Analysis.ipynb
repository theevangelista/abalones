# %%
import os
os.chdir('..')
import numpy as np
import pandas as pd
import seaborn as sns
import missingno as gno
import matplotlib
from common.dataset import load_abalones
from matplotlib import pyplot as plt

# %%
data = load_abalones()
data.head()
# Out:
#   sex  length  diameter  height  whole_weight  shucked_weight  viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    shell_weight  rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
# check for missing data
gno.matrix(data)

# %% [markdown]
# There is currently no missing points on the data set.

# %%
data = pd.get_dummies(data)

# %%
sns.pairplot(data)

# %%
# check correlations
sns.heatmap(data.corr(), linewidths=.5, annot=True)

# %% [markdown]
# We see that the length is high correlated with many of the features, and almost the same correlation with the number of rings, so we add it to removal. The same goes to the types of weights we can consider only the shell weight for this, since our assumption is that the older the bigger an abalone comes.
#
# The data is enought clean and with the pairplot we can have a nice visualization of the data distribution. Further preprocessing, feature selection and modeling will take place on experiment notebooks.
